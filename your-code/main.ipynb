# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math
from math import factorial as fac
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""
overall = 100
apples = 60
oranges = 40

p = apples / 100
q = oranges / 100

print("probability of an apple:", p)
print("probability of an orange:", q)
# Out:
# probability of an apple: 0.6
# probability of an orange: 0.4

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# What is the probability that the first 5 fruits are all apples?
p_apple_first_5 = p ** 5
apple_first_5_oranges_15 = p_apple_first_5 * q ** 15

print("probability of first 5 being an apple:", round(p_apple_first_5, 3))
print("probability of first 5 being an orange and then the next 15 being oranges:", round(apple_first_5_oranges_15,3))
# Out:
# probability of first 5 being an apple: 0.078
# probability of first 5 being an orange and then the next 15 being oranges: 0.0

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# your solution here
n = 20  # draws in total
k = 5   # apples to be drawn

binomial_coefficient = fac(n) / ((fac(k) * fac(n - k)))
prob_5_apples_15_oranges = binomial_coefficient * (p**k) * (1 - p)**(n - k)
print(prob_5_apples_15_oranges)

print("probability of 5 apples and 15 oranges out of 20 drwas:", round(prob_5_apples_15_oranges,3))
# Out:
# 0.0012944935222876579
# probability of 5 apples and 15 oranges out of 20 drwas: 0.001

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here
n = 20      # draws in total
p = 0.6     # probability of drawing an apple
prob = 0    # init
list_of_prob = []

for k in range(0,5):
    binomial_coefficient = fac(n) / ((fac(k) * fac(n - k)))
    prob_n_apple = binomial_coefficient * (p**k) * (1 - p)**(n - k)
    print(f"\nprobability of exactly {k} apple(s):", round(prob_n_apple,3))
    prob += prob_n_apple
    list_of_prob.append([k, prob_n_apple])

print(f"\nprobability of < {k+1} apple(s):", round(prob,3))
# Out:
# probability of exactly 0 apple(s): 0.0
#
# probability of exactly 1 apple(s): 0.0
#
# probability of exactly 2 apple(s): 0.0
#
# probability of exactly 3 apple(s): 0.0
#
# probability of exactly 4 apple(s): 0.0
#
# probability of < 5 apple(s): 0.0

# %% [markdown]
# <!-- **Plot the PDF (probability distributiom function) for the above binomial distribution.** -->
#
# **Plot the Probability Mass Function (PMF) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here
# Please label the axes and give a title to the plot 
df = pd.DataFrame(list_of_prob)
df.columns = ["k", "p"]
plt.xlabel("number of apples (k)")
plt.ylabel("probability")
plt.title("PMF of Binomial Distribution (n=20, p=0.6)")
plt.bar(df.k, df.p)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
# your code here 
k = 5           # 5 goals to be scored in a match
avg = 2.3       # average of goals scored per game

prob = ((avg**k) / (fac(k))) * (math.exp(-avg))
print(f"probability of exactly 5 goals:", round(prob,3))
# Out:
# probability of exactly 5 goals: 0.054

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot 
list_of_prob_0_10 = []

for k in range(0,11):
    prob = ((avg**k) / (fac(k))) * (math.exp(-avg))
    list_of_prob_0_10.append([k, prob])

df = pd.DataFrame(list_of_prob_0_10)
df.columns = ["k", "p"]
plt.xlabel("number of goals (k)")
plt.ylabel("probability")
plt.title("Poisson Distribution for the number of goals between 0 to 10")
plt.bar(df.k, df.p)
# Out:
# <BarContainer object of 11 artists>
